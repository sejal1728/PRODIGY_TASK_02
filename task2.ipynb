# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dataset=pd.read_csv("C:\\Users\\sejalpatil1728\\Downloads\\train.csv")

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
dataset.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
cols=['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
i=1,2,4,5,6,7,9

fig = plt.figure(figsize=(5, 5))
plt.hist(dataset['Survived'], color="#000080",bins=10)
plt.xlabel('Survived')
plt.show()

# %%
fig = plt.figure(figsize=(5, 5))
plt.hist(dataset['Sex'], color="#000080",bins=10)
plt.xlabel('Sex')
plt.show()

# %%
fig = plt.figure(figsize=(5, 5))
plt.hist(dataset['Age'], color="#000080",bins=10)
plt.xlabel('Age')
plt.show()

# %%
dataset.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dataset.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
dataset.shape
# Out:
# (891, 12)

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Selecting only numeric columns
numeric_columns = dataset.select_dtypes(include=[np.number])
# Grouping by 'Survived' and calculating the mean for numeric columns only
result = numeric_columns.groupby(dataset['Survived']).mean()
result
# Out:
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Survived
# 0          447.016393       0.0  2.531876  30.626179  0.553734  0.329690
# 1          444.368421       1.0  1.950292  28.343690  0.473684  0.464912
#
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %%
male=len(dataset[dataset['Sex']=='male'])
print("Number of male Survived",male)
# Out:
# Number of male Survived 577

# %%
female=len(dataset[dataset['Sex']=='female'])
print("Number of female Survived",female)
# Out:
# Number of female Survived 314

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
gender=['male','female']
index=[577,314]
ax.bar(gender,index)
plt.xlabel("Gender")
plt.ylabel("Number of People")
plt.show()

# %%
sns.heatmap(dataset.isnull(), yticklabels=False, cbar=False, cmap="viridis")
# Out:
# <Axes: >

# %%
alive=len(dataset[dataset['Survived']==1])
print("alive",alive)
dead=len(dataset[dataset['Survived']==0])
print("dead",dead)
# Out:
# alive 342
# dead 549

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
person=['alive','dead']
index=[342,549]
ax.bar(person,index)
plt.xlabel("Person")
plt.ylabel("Number of People")
plt.show()

# %%
dataset['Age'].mean()
# Out:
# 29.69911764705882

# %%
result = numeric_columns.groupby(by='Pclass')['Age'].mean()
result
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
#modified age
def modified_age(cols):
    Age=cols[0]
    Pclass=cols[1]
    if pd.isnull(Age):
        if Pclass==1:
            return 38
        elif Pclass==2:
            return 29
        else:
            return 25
    else:
        return(Age)

# %%
dataset['Age']=dataset[['Age','Pclass']].apply(modified_age,axis=1)
# Out:
# C:\Users\sejalpatil1728\AppData\Local\Temp\ipykernel_15184\662322900.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Age=cols[0]
# C:\Users\sejalpatil1728\AppData\Local\Temp\ipykernel_15184\662322900.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Pclass=cols[1]

# %%
sns.heatmap(dataset.isnull(), yticklabels=False, cbar=False, cmap="viridis")
# Out:
# <Axes: >

# %%
dataset.drop('Cabin',axis=1,inplace=True)

# %%
sns.heatmap(dataset.isnull(), yticklabels=False, cbar=False, cmap="viridis")
# Out:
# <Axes: >

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sex = pd.get_dummies(dataset['Sex'], drop_first=True).astype(int)
sex
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
embark= pd.get_dummies(dataset['Embarked'], drop_first=True).astype(int)
embark
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
dataset.drop(['Sex','Name','Embarked','Ticket'],axis=1,inplace=True)

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3  25.0      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
dataset=pd.concat([dataset,sex,embark],axis=1)

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0              1         0       3  22.0      1      0   7.2500     1  0  1
# 1              2         1       1  38.0      1      0  71.2833     0  0  0
# 2              3         1       3  26.0      0      0   7.9250     0  0  1
# 3              4         1       1  35.0      1      0  53.1000     0  0  1
# 4              5         0       3  35.0      0      0   8.0500     1  0  1
# ..           ...       ...     ...   ...    ...    ...      ...   ... .. ..
# 886          887         0       2  27.0      0      0  13.0000     1  0  1
# 887          888         1       1  19.0      0      0  30.0000     0  0  1
# 888          889         0       3  25.0      1      2  23.4500     0  0  1
# 889          890         1       1  26.0      0      0  30.0000     1  0  0
# 890          891         0       3  32.0      0      0   7.7500     1  1  0
#
# [891 rows x 10 columns]
